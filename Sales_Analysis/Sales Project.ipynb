# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
df['Total'] = df['Total'].astype(int)

# %%
total =list(df['Total'])
z=[]
t = 0
for i in range(len(total)):
    t= t + total[i]
    z.append(t)

y=[]
c=0
for i in range(len(df['Total'])):
    c=i
    y.append(c)
df['Total Sales'] = z
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%  Total       Date  \
# 0         Health and beauty       74.69         7  26.1415    548   1/5/2019
# 1    Electronic accessories       15.28         5   3.8200     80   3/8/2019
# ...

# %%
total =list(df['Total'])
t = 0
for i in range(len(total)):
    t= t + total[i]

t
# Out:
# 322469

# %%
plt.figure(figsize=(10,8))
plt.plot(df['Total Sales'],y,color="red")
plt.xlabel('Total Sales Amount')
plt.title('Total sales')
plt.xlim(0,500000)
plt.ylim(0,1200)
plt.grid()
plt.show()

# %%
df['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
 df_fs = df[df['Product line'] == 'Fashion accessories']
df_fs.drop(['Total Sales'],axis = 1)

total1 =list(df_fs['Total'])
z1=[]
t1 = 0
for i in range(len(total1)):
    t1= t1 + total1[i]
    z1.append(t1)

y1=[]
c1=0
for i in range(len(df_fs['Total'])):
    c1=i
    y1.append(c1)
df_fs['Total Sales'] = z1

total1 =list(df_fs['Total'])
t1 = 0
for i in range(len(total1)):
    t1= t1 + total1[i]

t1
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\923908348.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fs['Total Sales'] = z1
# 54223

# %%
df_fb = df[df['Product line'] == 'Food and beverages']
df_fb.drop(['Total Sales'],axis = 1)

total2 =list(df_fb['Total'])
z2=[]
t2 = 0
for i in range(len(total2)):
    t2= t2 + total2[i]
    z2.append(t2)
    
df_fb['Total Sales'] = z2

total2 =list(df_fb['Total'])
t2 = 0
for i in range(len(total2)):
    t2= t2 + total2[i]

t2
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\3612163200.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fb['Total Sales'] = z2
# 56056

# %%
df_ea = df[df['Product line'] == 'Electronic accessories']
df_ea.drop(['Total Sales'],axis = 1)

total3 =list(df_ea['Total'])
z3=[]
t3 = 0
for i in range(len(total3)):
    t3= t3 + total3[i]
    z3.append(t3)
df_ea['Total Sales'] = z3

total3 =list(df_ea['Total'])
t3 = 0
for i in range(len(total3)):
    t3= t3 + total3[i]

t3
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\1528284444.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ea['Total Sales'] = z3
# 54247

# %%
df_sp = df[df['Product line'] == 'Sports and travel']
df_sp.drop(['Total Sales'],axis = 1)

total4 =list(df_sp['Total'])
z4=[]
t4 = 0
for i in range(len(total4)):
    t4= t4 + total4[i]
    z4.append(t4)
df_sp['Total Sales'] = z4

total4 =list(df_sp['Total'])
t4 = 0
for i in range(len(total4)):
    t4= t4 + total4[i]

t4
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\4156051112.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sp['Total Sales'] = z4
# 55037

# %%
df_hl = df[df['Product line'] == 'Home and lifestyle']
df_hl.drop(['Total Sales'],axis = 1)

total5 =list(df_hl['Total'])
z5=[]
t5 = 0
for i in range(len(total5)):
    t5= t5 + total5[i]
    z5.append(t5)
df_hl['Total Sales'] = z5

total5 =list(df_hl['Total'])
t5 = 0
for i in range(len(total5)):
    t5= t5 + total5[i]

t5
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\1675469023.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hl['Total Sales'] = z5
# 53785

# %%
df_hb = df[df['Product line'] == 'Health and beauty']
df_hb.drop(['Total Sales'],axis = 1)

total6 =list(df_hb['Total'])
z6=[]
t6 = 0
for i in range(len(total6)):
    t6= t6 + total6[i]
    z6.append(t6)
df_hb['Total Sales'] = z6

total6 =list(df_hb['Total'])
t6 = 0
for i in range(len(total6)):
    t6= t6 + total6[i]

t6
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\1036501418.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hb['Total Sales'] = z6
# 49121

# %%
df['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title('Product Wise Analysis (by Amt of Sales)')
nh = [t1,t2,t3,t4,t5,t6]
mylabels = ['Fashion accessories','Food & beverages','Electronic accessories','Sports & travel','Home & lifestyle','Health & beauty']
plt.pie(nh , labels= mylabels, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Product line' , data= df , palette="Set1",order=df['Product line'].value_counts().index)
plt.xlabel('Product Name')
plt.ylabel('No of Units Sold')
plt.title('Product Wise Analysis (by unit of Sales)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\2605753167.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Product line' , data= df , palette="Set1",order=df['Product line'].value_counts().index)

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Product line' , data= df , palette="Set3",edgecolor="black",  hue=df['Branch'], order=df['Product line'].value_counts().index)
plt.xlabel('Product Name')
plt.ylabel('No of Units Sold')
plt.title('Product Wise Analysis (As per Branch)')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Product line' , data= df , palette="Set2",edgecolor="black",  hue=df['City'], order=df['Product line'].value_counts().index)
plt.xlabel('Product Name')
plt.ylabel('No of Units Sold')
plt.title('Product Wise Analysis (As per City)')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Branch' , data= df ,edgecolor="red",  palette="Set2",order=df['Branch'].value_counts().index)
plt.xlabel('Branch Name')
plt.ylabel('No of Units Sold')
plt.title('Branch Wise Analysis (by unit of Sales sold)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\3870621044.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Branch' , data= df ,edgecolor="red",  palette="Set2",order=df['Branch'].value_counts().index)

# %%
b1 = df[df['Branch']=='A']

tot1 =list(b1['Total'])
tb = 0
for i in range(len(tot1)):
    tb= tb + tot1[i]
tb
# Out:
# 106029

# %%
b2 = df[df['Branch']=='B']

tot2 =list(b2['Total'])
tb2 = 0
for i in range(len(tot2)):
    tb2= tb2 + tot2[i]
tb2
# Out:
# 106032

# %%
b3 = df[df['Branch']=='C']

tot3 =list(b3['Total'])
tb3 = 0
for i in range(len(tot3)):
    tb3= tb3 + tot3[i]
tb3
# Out:
# 110408

# %%
plt.figure(figsize=(10,8))
plt.title('Branch Wise Analysis (by Amt of Sales)')
nh = [tb,tb2,tb3]
mylabels = ['Branch A','Branch B','Branch C']
plt.pie(nh , labels= mylabels, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='City' , data= df , palette="Set1",order=df['City'].value_counts().index)
plt.xlabel('City Name')
plt.ylabel('No of Units Sold')
plt.title('City Wise Analysis (by unit of Sales sold)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\3987452750.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='City' , data= df , palette="Set1",order=df['City'].value_counts().index)

# %%
c1 = df[df['City']== 'Yangon']

toc1 =list(c1['Total'])
tc = 0
for i in range(len(toc1)):
    tc= tc + toc1[i]
tc
# Out:
# 106029

# %%
c2 = df[df['City']== 'Mandalay']

toc2 =list(c2['Total'])
tc2 = 0
for i in range(len(toc2)):
    tc2= tc2 + toc2[i]
tc2
# Out:
# 106032

# %%
c3 = df[df['City']== 'Naypyitaw']

toc3 =list(c3['Total'])
tc3 = 0
for i in range(len(toc3)):
    tc3= tc3 + toc3[i]
tc3
# Out:
# 110408

# %%
plt.figure(figsize=(10,8))
plt.title('City Wise Analysis (by Amt of Sales)')
nh = [tc,tc2,tc3]
mylabels = ['Yangon','Mandalay','Naypyitaw']
plt.pie(nh , labels= mylabels, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Gender' , data= df , palette="Set1",edgecolor = "black",order=df['Gender'].value_counts().index)
plt.xlabel('Gender')
plt.ylabel('No of Units Purchased')
plt.title('Gender Wise Analysis (by unit of Sales sold)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\3238083856.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender' , data= df , palette="Set1",edgecolor = "black",order=df['Gender'].value_counts().index)

# %%
g = df[df['Gender']== 'Female']

tog =list(g['Total'])
tg = 0
for i in range(len(tog)):
    tg= tg + tog[i]
tg
# Out:
# 167637

# %%
g1 = df[df['Gender']== 'Male']

tog1 =list(g1['Total'])
tg1 = 0
for i in range(len(tog1)):
    tg1= tg1 + tog1[i]
tg1
# Out:
# 154832

# %%
plt.figure(figsize=(10,8))
plt.title('Gender Wise Analysis (by Amt of Sales)')
nh = [tg,tg1]
mylabels = ['Female','Male']
plt.pie(nh , labels= mylabels, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Branch' , data= df , palette="Set1",hue=df['Gender'],edgecolor = "black", order=df['Branch'].value_counts().index)
plt.xlabel('Branch Name')
plt.ylabel('No of Units Sold')
plt.title('Branch Wise Analysis (by unit of Sales sold)')
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='City' , data= df , palette="Set1",hue=df['Gender'],edgecolor = "black")
plt.xlabel('City Name')
plt.ylabel('No of Units Sold')
plt.title('City Wise Analysis (by unit os sales)')
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Product line' , data= df , palette="Set2",edgecolor="black",  hue=df['Gender'], order=df['Product line'].value_counts().index)
plt.xlabel('Product Name')
plt.ylabel('No of Units Sold')
plt.title('Product Wise Analysis (As per Gender)')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Customer type' , data= df , palette="Set3",edgecolor = "black", order=df['Customer type'].value_counts().index)
plt.xlabel('Type of Customer')
plt.ylabel('No of Units Purchased')
plt.title('Customer Type Analysis (by unit of Sales sold)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\423831073.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Customer type' , data= df , palette="Set3",edgecolor = "black", order=df['Customer type'].value_counts().index)

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Branch' , data= df , palette="Set2",hue=df['Customer type'],edgecolor="black",  order=df['Branch'].value_counts().index)
plt.xlabel('Branch Name')
plt.ylabel('No of Units Sold')
plt.title('Branch Wise Analysis (by unit of Sales sold)')
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='City' , data= df , palette="Set1",hue=df['Customer type'],edgecolor = "black")
plt.xlabel('City Name')
plt.ylabel('No of Units Sold')
plt.title('City Wise Analysis (on Gender basis)')
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Product line' , data= df , palette="Set3",edgecolor="black",  hue=df['Customer type'], order=df['Product line'].value_counts().index)
plt.xlabel('Product Name')
plt.ylabel('No of Units Sold')
plt.title('Product Wise Analysis (As per Customer Type)')
plt.show()

# %%
df['Month'] = df['Date'].apply(lambda x: x.split('/')[0])

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Month', data= df , palette="Set1",edgecolor = "black")
plt.xlabel('Type of Customer')
plt.ylabel('No of Units Sold')
plt.title('Month Wise Sales Analysis (by units sold)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\3805106461.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Month', data= df , palette="Set1",edgecolor = "black")

# %%
m1 = df[df['Month']== '1']

tom1 =list(m1['Total'])
tm = 0
for i in range(len(tom1)):
    tm= tm + tom1[i]
tm
# Out:
# 116119

# %%
m2 = df[df['Month']== '2']

tom2 =list(m2['Total'])
tm2 = 0
for i in range(len(tom2)):
    tm2= tm2 + tom2[i]
tm2
# Out:
# 97070

# %%
m3 = df[df['Month']== '3']

tom3 =list(m3['Total'])
tm3 = 0
for i in range(len(tom3)):
    tm3= tm3 + tom3[i]
tm3
# Out:
# 109280

# %%
plt.figure(figsize=(10,8))
plt.title('Month Wise Analysis (by Amt of Sales)')
nh = [tm,tm2,tm3]
mylabels = ['Januvary','Februvary','March']
plt.pie(nh , labels= mylabels, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Month' , data= df , palette="Set1",edgecolor="black",  hue=df['Product line'])
plt.xlabel('Month Number')
plt.ylabel('No of Units Sold')
plt.title('Month Wise Analysis (As per Product)')
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Month' , data= df , palette="Set1",edgecolor="black",  hue=df['Gender'])
plt.xlabel('Month Number')
plt.ylabel('No of Units Sold')
plt.title('Month Wise Analysis (As per Gender)')
plt.show()

# %%
df['Exact_time'] = df['Time'].apply(lambda x: x.split(':')[0])

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Exact_time', data= df , palette="Set1",edgecolor = "black", order=df['Exact_time'].value_counts().index)
plt.xlabel('Time (in 24 Hrs Format)')
plt.ylabel('No of Units Sold')
plt.title('Time Wise Sales Analysis (by units sold)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\543216255.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Exact_time', data= df , palette="Set1",edgecolor = "black", order=df['Exact_time'].value_counts().index)

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Month' , data= df , palette="Set2",edgecolor="black",  hue=df['Exact_time'])
plt.xlabel('Month Number')
plt.ylabel('No of Units Sold')
plt.title('Time Wise Analysis (As per Month)')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Product line' , data= df , palette="Set2",edgecolor="black",  hue=df['Exact_time'])
plt.xlabel('Product Name')
plt.ylabel('No of Units Sold')
plt.title('Time Wise Analysis (As per Product)')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='Gender' , data= df , palette="Set2",edgecolor="black",  hue=df['Exact_time'])
plt.xlabel('Gender')
plt.ylabel('No of Units Sold')
plt.title('Time Wise Analysis (As per Gender)')
plt.grid()
plt.show()

# %%
avg=list(df['Rating'])
avt=0
for i in range(len(avg)):
    avt= avt + avg[i]

avg_r = avt/1000
avg_r

ya=[]
for i in range(len(df['Rating'])):
    ya.append(i)
az=[]
n=0
s=0

# %%
plt.rcParams["figure.figsize"] = [16,10]
plt.rcParams["figure.autolayout"] = True
plt.scatter(df['Rating'],ya )
plt.xlim(0,10)
plt.xlabel('Ratings')
plt.ylabel('No of Customers')
plt.title('Ratings Of Customers')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Payment', data= df , palette="Set1",edgecolor = "black", order=df['Payment'].value_counts().index)
plt.xlabel('Payment Mode')
plt.ylabel('No of Units Sold')
plt.title('Payment Mode Wise Sales Analysis (by units sold)')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1780\1667016827.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Payment', data= df , palette="Set1",edgecolor = "black", order=df['Payment'].value_counts().index)

# %%
p = df[df['Payment']== 'Ewallet']

top1 =list(p['Total'])
tp = 0
for i in range(len(top1)):
    tp= tp + top1[i]
tp
# Out:
# 109812

# %%
p2 = df[df['Payment']== 'Cash']

top2 =list(p2['Total'])
tp2 = 0
for i in range(len(top2)):
    tp2= tp2 + top2[i]
tp2
# Out:
# 112047

# %%
p3 = df[df['Payment']== 'Credit card']

top3 =list(p3['Total'])
tp3 = 0
for i in range(len(top3)):
    tp3= tp3 + top3[i]
tp3
# Out:
# 100610

# %%
plt.figure(figsize=(10,8))
plt.title('Payment Mode Wise Analysis (by Amt of Sales)')
nh = [tp,tp2,tp3]
mylabels = ['E-Wallet','Cash','Credit Card']
plt.pie(nh , labels= mylabels, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(18,11))
sns.countplot(x='Payment' , data= df , palette="Set1",edgecolor="blue",  hue=df['Gender'])
plt.xlabel('Payment Mode')
plt.ylabel('No of Units Sold')
plt.title('Payment Mode Wise Analysis (As per Gender)')
plt.show()

# %%
plt.figure(figsize=(18,11))
sns.countplot(x='Month' , data= df , palette="Set1",edgecolor="black",  hue=df['Payment'])
plt.xlabel('Month No')
plt.ylabel('No of Units Sold')
plt.title('Payment Mode Wise Analysis (As per Month)')
plt.show()

# %%
plt.figure(figsize=(18,13))
sns.countplot(x='City' , data= df , palette="Set2",edgecolor="black",  hue=df['Payment'])
plt.xlabel('City Name')
plt.ylabel('No of Units Sold')
plt.title('Payment Mode Wise Analysis (As per City)')
plt.grid()
plt.show()
